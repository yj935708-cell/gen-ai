# %% [markdown]
# <a href="https://colab.research.google.com/github/yj935708-cell/gen-ai/blob/main/Copy_of_python_for_generative_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
variable is a container to store information and retrieve it latter
# Out:
#   File "/tmp/ipython-input-176615221.py", line 1
#     variable is a container to store information and retrieve it latter
#                   ^
# SyntaxError: invalid syntax

# %%
x=10

# %%
x

# %%
10

# %%
#rules for naming variable
#starting position of variable are underscore or letter
my_sub="python"
my_sub
# Out:
# 'python'

# %%
_mycity = "solan"
_mycity

'solan'
# Out:
# 'solan'

# %%
my_sub = "python"
print(my_sub)
# Out:
# python

# %%
#remaining part of variable are letter, underscore or number
my_sub1 = "Science'
my_sub1
# Out:
#   File "/tmp/ipython-input-3264623642.py", line 2
#     my_sub1 = "Science'
#               ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
#for variable naming we can not use number on first position
1my_sub="mathe"
# Out:
#   File "/tmp/ipython-input-79424000.py", line 2
#     1my_sub="mathe"
#     ^
# SyntaxError: invalid decimal literal

# %%
#variables does not contain space or symbole
my@sub="machine learning"
my@sub
# Out:
#   File "/tmp/ipython-input-1928799022.py", line 2
#     my@sub="machine learning"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
#python are case sensitive,variable names such as my_sub, MY_SUB are diff
my_sub ="Machine learning"
MY_SUB ="Deep learning"
my_sub
# Out:
# 'Machine learning'

# %%
#keyword -- reserved word in python is known as keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#data type
#numeric
#integer--absence of decimal point is known as integer
#ex -- 1,2,3,4
x = 1
type(x) # type() is function thet return type of data
# Out:
# int

# %%
#floating point number --presence of decimal
#ex -- 3.14, 7.14
y = 3.14
type(y)
# Out:
# float

# %%
#boolean--it is used to store values in the form of true and false
a = true
type(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-452600920.py in <cell line: 0>()
#       1 #boolean--it is used to store values in the form of true and false
# ----> 2 a = true
#       3 type(a)
#
# NameError: name 'true' is not defined

# %%
b = False
type(b)
# Out:
# bool

# %%
#None--it is define null value means nothing
e = None
type(e)
# Out:
# NoneType

# %%
my_sub = "Machine learning"
print(my_sub)
# Out:
# Machine learning

# %%
type(my_sub)
# Out:
# str

# %%
my_college = 'shoolini unniversity'
type(my_college)
# Out:
# str

# %%
my_sentence = '''This is multiple line sentence, so this also a string'''
type(my_sentence)
# Out:
# str

# %%
my_sub = "machine learning"
len(my_sub)
# Out:
# 16

# %%
my_sub[0]
# Out:
# 'm'

# %%
my_sub[-15]
# Out:
# 'a'

# %%
my_sub[-1]
# Out:
# 'g'

# %%
my_sub = "Machine learning"
my_sub[0:7:1]
# Out:
# 'Machine'

# %%
my_sub[8::1]
# Out:
# 'learning'

# %%
my_sub[0:15:2]
# Out:
# 'Mcielann'

# %%
#method of string
my_sub = "PYTHON"
my_sub.lower()
# Out:
# 'python'

# %%
my_sub = "Machine learning"
my_sub.upper()
# Out:
# 'MACHINE LEARNING'

# %%
my_sub.count("a")
# Out:
# 2

# %%
my_list = [78,89,34,56]
type(my_list)
# Out:
# list

# %%
mixed_list = ["apple",24,3.14,True,None]
type(mixed_list)
# Out:
# list

# %%
my_list = [78,84,56,34]
my_list[0]
# Out:
# 78

# %%
my_list[-1]
# Out:
# 34

# %%
my_list = [2,7,8,4,5,6]
my_list[0:5:1]
# Out:
# [2, 7, 8, 4, 5]

# %%
my_list[0:5]
# Out:
# [2, 7, 8, 4, 5]

# %%
my_list[0:]
# Out:
# [2, 7, 8, 4, 5, 6]

# %%
my_list[:5]
# Out:
# [2, 7, 8, 4, 5]

# %%
my_list[::-1]
# Out:
# [6, 5, 4, 8, 7, 2]

# %%
my_list[0:5:-1]
# Out:
# []

# %%
my_list = [2,7,8,4,3]
sum(my_list)
# Out:
# 24

# %%
#sorted() --this function arrange list in increasing order or decreasing
my_list = [89,67,45,12,34]
sorted(my_list, reverse = True)
# Out:
# [89, 67, 45, 34, 12]

# %%
my_list
# Out:
# [89, 67, 45, 12, 34]

# %%
#append()--thid method add item end of the list,item take as argument
list1 = [9,8,7,4]
list1.append(100)
list1
# Out:
# [9, 8, 7, 4, 100]

# %%
#extend()--this method merge list into another list
list1 = [9,8,7,4]
list2 = [100,200,300]
list1.extend(list2)
list1

# %%
#pop()--this method remove item form the list,and take index as a argument
my_list = [90,87,56,34,100]
my_list.pop(1)
# Out:
# 87

# %%
my_list
# Out:
# [90, 56, 34, 100]

# %%
#reverse()--this method reverse a list
my_list = [90,87,56,52]
my_list.reverse()

# %%
my_list
# Out:
# [52, 56, 87, 90]

# %%
my_dict = {"Name":"Abhishek","College":"Shoolini"}
print(my_dict["Name"])
print(my_dict["college"])
# Out:
# Abhishek
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3057702621.py in <cell line: 0>()
#       1 my_dict = {"Name":"Abhishek","College":"Shoolini"}
#       2 print(my_dict["Name"])
# ----> 3 print(my_dict["college"])
#
# KeyError: 'college'

# %%
#keys()--this method find keys of dictionary
list(my_dict.keys())
# Out:
# ['Name', 'College']

# %%
#values()--this method find number of values in dictionary
list(my_dict.values())
# Out:
# ['Abhishek', 'Shoolini']

# %%
#items()--this method find items in dictionary
list(my_dist.items())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-764239376.py in <cell line: 0>()
#       1 #items()--this method find items in dictionary
# ----> 2 list(my_dist.items())
#
# NameError: name 'my_dist' is not defined

# %%
#get()--this method find value and key take as argument
my_dict.get("Name")
# Out:
# 'Abhishek'

# %%
print(my_dict.get("Age","Age is not found"))
# Out:
# Age is not found

# %%
#update()--this method update the dictionary and take dictionary as argu
my_dict.update({"Age":20})
my_dict
# Out:
# {'Name': 'Abhishek', 'College': 'Shoolini', 'Age': 20}

# %%
my_dict.update({"Name":"Abhishek"})
my_dict
# Out:
# {'Name': 'Abhishek', 'College': 'Shoolini', 'Age': 20}

# %%
#zip()--this function take pair of list as argument and return python ob
state_list = ["HP","UP","MP"]
city_list = ["SHM","LUCK","BHOPAL"]
dict(zip(state_list, city_list))
# Out:
# {'HP': 'SHM', 'UP': 'LUCK', 'MP': 'BHOPAL'}

# %%
list(zip(state_list,city_list))
# Out:
# [('HP', 'SHM'), ('UP', 'LUCK'), ('MP', 'BHOPAL')]

# %%
#conditional statement
#if--this execute when condition is true
#elif--this execute when condition is true
#else--this execute when if and elif condition false
age = int(input("Enter your age:"))
if age>60:
  print("You are too old for marry")
elif age<18:
  print("You are too young for marry")
else:
  print("we will find perfect match for you")
# Out:
# Enter your age:20
# we will find perfect match for you

# %%
my_sub = "python"
print(my_sub[0])
print(my_sub[1])
print(my_sub[2])
print(my_sub[3])
# Out:
# p
# y
# t
# h

# %%
my_sub = "python"
for i in my_sub:
  print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in range(0,6,1):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(0,6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
my_list = [90,78,65,45]
for i in my_list:
  print(i)
# Out:
# 90
# 78
# 65
# 45

# %%
#while loop
i = 0 #initialization
while i<5:
  print(i)
  i+=1
  print(i)
# Out:
# 0
# 1
# 1
# 2
# 2
# 3
# 3
# 4
# 4
# 5

# %%
i = 0
while i<5:
  i+=1
  if i == 3:
    break
  else:
    print(i)
# Out:
# 1
# 2

# %%
i=0
while i<5:
  i+=1
  if i==3:
    continue
    print(i)
  else:
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
i=0
while i<5:
  i+=1
  if i==3:
    pass
    print(i)
  else
    print(i)
# Out:
#   File "/tmp/ipython-input-524556440.py", line 7
#     else
#         ^
# SyntaxError: expected ':'

# %%
#user defined function without argument
def add():
  a = int(input("Enter first number:"))
  b = int(input("Enter seceond number:"))
  return a+b

# %%
print(add())
# Out:
# Enter first number:10
# Enter seceond number:5
# 15

# %%
#possible argument
def calculation(a,b):
  print("Addition:",a+b)
  print("subtraction:",a-b)
  print("multiplication:",a*b)
  print("division:",a\b)
  return "calculation is complete"
# Out:
#   File "/tmp/ipython-input-2499487184.py", line 6
#     print("division:",a\b)
#                         ^
# SyntaxError: unexpected character after line continuation character

# %%
print(calculation(10,5))

# %%
#default argument
def area_perimeter(width = 4,height = 8:)
area = width*height
perimeter = 2*(width+height)
return "Area of rectangle is",area,"and perimeter is",perimeter
# Out:
#   File "/tmp/ipython-input-1247832608.py", line 2
#     def area_perimeter(width = 4,height = 8:)
#                                            ^
# SyntaxError: invalid syntax

# %%
print(area_perimeter(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-988569284.py in <cell line: 0>()
# ----> 1 print(area_perimeter(10))
#
# NameError: name 'area_perimeter' is not defined

# %%
#keyword argument
def interest(p,r,t):
  i=(p*r*t)/100
  return i

# %%
print(interest(r=10,t=2,p=1000))
# Out:
# 200.0

# %%
non keyword variable length argument
def test(args):
  print(args)
  print(len(args))
  print(type(args))
# Out:
#   File "/tmp/ipython-input-2980645653.py", line 1
#     non keyword variable length argument
#         ^
# SyntaxError: invalid syntax

# %%
def sum-number(*args) sum number(1,2,3,4,5)
sum=0
for num in args:  args=(1,2,3,4,5)
  sum+=num
  return sum
# Out:
#   File "/tmp/ipython-input-2521505300.py", line 1
#     def sum-number(*args) sum number(1,2,3,4,5)
#            ^
# SyntaxError: expected '('

# %%
def test(**kwargs)
print(kwargs)
print(len(kwargs))
print(type(kwargs))
test("a":10,"b":20,"c":30)
# Out:
#   File "/tmp/ipython-input-2917333160.py", line 1
#     def test(**kwargs)
#                       ^
# SyntaxError: expected ':'

# %%
import numpy as np

# %%
#one dimensional array
oned_array = np.array([1,2,3])
print(oned_array)
# Out:
# [1 2 3]

# %%
#two dimensional array
twod_array = np.array([[1,2,3],[4,5,6]])
print(twod_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
row_vector = np.array([[1,2,3]])
print(row_vector)
# Out:
# [[1 2 3]]

# %%
print(row_vector.transpose())
# Out:
# [[1]
#  [2]
#  [3]]

# %%
#ndim --find the dimension
print(row_vector.ndim)
# Out:
# 2

# %%
#size ---find the number of item
print(row_vector.size)
# Out:
# 3

# %%
print(twod_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#shape--find number of row and column in two dimensional array
print(twod_array.shape)
# Out:
# (2, 3)

# %%
print(row_vector)
# Out:
# [[1 2 3]]

# %%
print(row_vector.shape)
# Out:
# (1, 3)

# %%
threed_array = np.random.randint(1,20,(2,3,4))
print(threed_array)
# Out:
# [[[ 6 19 10  5]
#   [ 7  2  6 19]
#   [ 9 10 11  9]]
#
#  [[ 3 17  3  1]
#   [18 12 18 14]
#   [ 8 16 19  2]]]

# %%
print(threed_array.shape)
# Out:
# (2, 3, 4)

# %%
import numpy as mp

# %%
zeros_array = np zeroes((3,3))
print(zeros_array)
# Out:
#   File "/tmp/ipython-input-2287556032.py", line 1
#     zeros_array = np zeroes((3,3))
#                      ^
# SyntaxError: invalid syntax

# %%
Zeros_array = np zeros((3,3),dtype = int)
# Out:
#   File "/tmp/ipython-input-3917432713.py", line 1
#     Zeros_array = np zeros((3,3),dtype = int)
#                      ^
# SyntaxError: invalid syntax

# %%
import numpy as np
ones_array= np ones((3,3))
print(ones_array)
# Out:
#   File "/tmp/ipython-input-39887783.py", line 2
#     ones_array= np ones((3,3))
#                    ^
# SyntaxError: invalid syntax

# %%
import numpy as np
mat1 = np.matrix("1,2,3;4,5,6;7,8,9")
print(mat1)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
import numpy as np
mat2 = np.random.randint(1,10,(3,3))
print(mat2)
# Out:
# [[1 2 2]
#  [6 6 4]
#  [2 3 2]]

# %%
import numpy as np
mat3 = np.random.random((3,3))
print(mat3)
# Out:
# [[0.01169852 0.31519364 0.99589209]
#  [0.06792126 0.43189406 0.17008891]
#  [0.42804744 0.62268242 0.79707782]]

# %%
import numpy as np
my_array = np.array([1,2,3])
print(my_array)
# Out:
# [1 2 3]

# %%
import numpy as np
power_array = np.power(my_array,2)
print(power_array)
# Out:
# [1 4 9]

# %%
import numpy as np
log_array = np.log(my_array)
print(log_array)
# Out:
# [0.         0.69314718 1.09861229]

# %%
import numpy as np
log2_array = np.log2(my_array)
print(log2_array)
# Out:
# [0.        1.        1.5849625]

# %%
import numpy as np
log10_array = np.log1o(my_array)
print(log10)

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint = np array([1,3])
ypoint = np array([2,4])
plt.plot(xpoint,ypoint)
plot show()
# Out:
#   File "/tmp/ipython-input-1598823208.py", line 3
#     xpoint = np array([1,3])
#                 ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np
cgpa = np.array([6,7,8,9,10])
package = np.array([4,5,6,7,9])
plt.plot(cgpa,package)
plt.xlabel("CGPA")
plt.ylabel("package in lpa")
plt.title("shoolini unniversity students data")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
cgpa = np.array([6,7,8,9,10])
package = np.array([4,5,6,7,9])
plt.plot(cgpa,package,"*:g",ms=15,mlc="red",mfc = "orange",linewidth = 5)
plt.xlabel("CGPA")
plt.ylabel("package in lpa")
plt.title("shoolini unniversity students data")
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2541384179.py in <cell line: 0>()
#       3 cgpa = np.array([6,7,8,9,10])
#       4 package = np.array([4,5,6,7,9])
# ----> 5 plt.plot(cgpa,package,"*:g",ms=15,mlc="red",mfc = "orange",linewidth = 5)
#       6 plt.xlabel("CGPA")
#       7 plt.ylabel("package in lpa")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1775         """
#    1776         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777         lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778         for line in lines:
#    1779             self.add_line(line)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in __call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295                 this += args[0],
#     296                 args = args[1:]
# --> 297             yield from self._plot_args(
#     298                 axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299                 return_kwargs=return_kwargs
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     544             return list(result)
#     545         else:
# --> 546             return [l[0] for l in result]
#     547
#     548
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in <genexpr>(.0)
#     537                 f"data, but found {len(label)} for {n_datasets} datasets.")
#     538
# --> 539         result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     540                               {**kwargs, 'label': label})
#     541                   for j, label in enumerate(labels))
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _make_line(self, axes, x, y, kw, kwargs)
#     336         kw = {**kw, **kwargs}  # Don't modify the original kw.
#     337         self._setdefaults(self._getdefaults(kw), kw)
# --> 338         seg = mlines.Line2D(x, y, **kw)
#     339         return seg, kw
#     340
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     405         # update kwargs before updating data to give the caller a
#     406         # chance to init axes (and hence unit support)
# --> 407         self._internal_update(kwargs)
#     408         self.pickradius = pickradius
#     409         self.ind_offset = 0
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _internal_update(self, kwargs)
#    1231         The lack of prenormalization is to maintain backcompatibility.
#    1232         """
# -> 1233         return self._update_props(
#    1234             kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235             "{prop_name!r}")
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in _update_props(self, props, errfmt)
#    1204                     func = getattr(self, f"set_{k}", None)
#    1205                     if not callable(func):
# -> 1206                         raise AttributeError(
#    1207                             errfmt.format(cls=type(self), prop_name=k),
#    1208                             name=k)
#
# AttributeError: Line2D.set() got an unexpected keyword argument 'mlc'

# %%
#bar plot--it work on numerical as wll as categorical data
import matplotlib.pylot as np
import numpy as np
fruit = np.array(["apple","banana","orange","watermelon"])
quantity = np.array([100,120,80,70])
color = np.array(["red","yellow","orange","green"])
plt.bar(fruit,quantity,color = color)
plt.xlabel("Fruit")
plt.ylabel("quantity of fruit")
plt.title("fruit vs fruit quantity")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1044583607.py in <cell line: 0>()
#       1 #bar plot--it work on numerical as wll as categorical data
# ----> 2 import matplotlib.pylot as np
#       3 import numpy as np
#       4 fruit = np.array(["apple","banana","orange","watermelon"])
#       5 quantity = np.array([100,120,80,70])
#
# ModuleNotFoundError: No module named 'matplotlib.pylot'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#pie plot
percentage of fruit = np.array([20,25,30,25])
fruit = np.array(["apple","banana","orange","watermelon"])
myexplode = np.array([0.2,0,0,0])
plt.pie(percentage_of_fruit,labels = fruit,explode = myexplode)
plt.legend(title = "fruit",loc = "best")
plt.show()
# Out:
#   File "/tmp/ipython-input-413630501.py", line 2
#     percentage of fruit = np.array([20,25,30,25])
#                ^
# SyntaxError: invalid syntax

# %%
age_of_car = np.array([4,,5,6,7,8,9,10,12,14])
speed_of_car = np.array([150,140,120,110,100,90,80,70,60])
plt.scatter(age_of_car,speed_of_car)
plt.xlabel("Age of car")
plt.ylabel("Speed of car")
plt.title("Age of car vs speed of car")
plt.show()
# Out:
#   File "/tmp/ipython-input-142816380.py", line 1
#     age_of_car = np.array([4,,5,6,7,8,9,10,12,14])
#                              ^
# SyntaxError: invalid syntax

# %%
#histogram--it showing the frequency distribution of the data
import numpy as np
x = np.random.randint(40,100,(1,200))
x=x.flatten()
print(x)
# Out:
# [74 54 93 56 41 40 49 47 55 46 72 91 53 98 81 92 41 65 97 80 80 63 95 95
#  99 60 59 54 86 50 87 55 69 57 99 75 50 71 45 83 81 57 84 82 96 83 79 49
#  50 68 81 69 86 51 52 70 95 57 92 74 68 81 93 86 66 98 60 60 94 86 46 57
#  84 64 57 78 67 76 84 64 65 60 69 68 74 79 57 93 77 74 95 86 48 97 47 86
#  82 82 93 77 98 76 98 41 55 46 81 69 79 87 82 77 85 57 91 84 41 87 95 93
#  50 80 74 98 51 99 90 58 99 45 67 45 78 69 79 80 62 86 97 51 81 68 73 95
#  51 66 82 95 80 75 83 86 40 97 94 50 50 82 60 56 94 50 89 41 92 57 44 59
#  54 43 43 91 85 93 89 59 69 90 54 86 90 86 90 92 54 81 97 70 99 79 44 98
#  42 41 66 98 79 59 86 86]

# %%
import matplotlib.pyplot as plt
plt.hist(x, bins = 10)
plt.show()

# %%
plt.hist(x,bins = 20)
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.title("Marks vs Frequency")
plt.show()

# %%
import pandas as pd

# %%
my_series = pd.Series(["Apple","Banana","Orange","watermelon"],name = "Fruit")
my_series
# Out:
# 0         Apple
# 1        Banana
# 2        Orange
# 3    watermelon
# Name: Fruit, dtype: object

# %%
df = pd.Dataframe(["Apple",100],["Banana",120],["Orange",80],["watermelon",50],columns = ["Fruit","Quantity"])
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2300795376.py in <cell line: 0>()
# ----> 1 df = pd.Dataframe(["Apple",100],["Banana",120],["Orange",80],["watermelon",50],columns = ["Fruit","Quantity"])
#       2 df
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
import pandas as pd

# %%
#fetch the data from bottom
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1698072449.py in <cell line: 0>()
#       1 #fetch the data from bottom
# ----> 2 df.tail()
#
# NameError: name 'df' is not defined

# %%
#find the duplicate value
df.duplicate().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-897408244.py in <cell line: 0>()
#       1 #find the duplicate value
# ----> 2 df.duplicate().sum()
#
# NameError: name 'df' is not defined

# %%
#find the null value
df.isnull().sum()

# %%
#find the unique value in particular column
df["original_language"].unique()

# %%
#find the number of unique value
df["original_language"].nunique()

# %%
hindi_movie = df[df["original_language"] == "hii"]
hindi_movie

# %%
#how to write csv file
hindi_movie.to_csv("hindi_movie.csv")

# %%
linear regression
it is supervised ml solved regression based problem
there are three type of linear regression
1.simple linear regression
2.multiple linear regression
3.polynomial linear regression

# %%
from transformers import pipeline

summarizer = pipeline("summarization",model="facebook/bart-large-cnn")

 text = """The global shift toward renewable eenergy is accelerating'
 driven by corners over climate change and energy security.solar
 and wind power installations have reached record levels worldwide."""


 summary = summarizer(text,max_length=30,min_length=10,do_sample=False)

 print(summary[0])
# Out:
#   File "/tmp/ipython-input-946588452.py", line 5
#     text = """The global shift toward renewable eenergy is accelerating'
#     ^
# IndentationError: unexpected indent

# %%
from transformers import AutoTokenizer
